# %% [markdown]
# Code to demonstrate basic FastCDA capabilities in a Jupyter notebook.

# %%
from fastcda import FastCDA
from dgraph_flex import DgraphFlex
import semopy
import pprint as pp

# create  an instance of FastCDA
fc = FastCDA()

# %%
# read in the sample ema dataset and view it
df = fc.getSampleData('R34B01.csv')
df
# Out:
#     PainIntensity  PainControl  PainConcerned  PainAffectFunc  \
# 0       -0.165406     0.294884      -0.151717       -0.229416
# 1       -0.165406     0.294884      -0.151717       -0.229416
# 2       -0.165406     0.294884      -0.151717       -0.229416
# 3       -0.165406     0.294884      -0.151717       -0.229416
# 4       -0.165406     0.294884      -0.151717       -0.229416
# ..            ...          ...            ...             ...
# 75      -2.055755     0.294884      -0.151717       -0.229416
# 76      -2.055755     0.294884      -0.151717       -0.229416
# 77      -0.165406     0.294884      -0.151717       -0.229416
# 78      -0.165406     0.294884      -0.151717       -0.229416
# 79      -0.165406     0.294884      -0.151717       -0.229416
#
#     PainFearfulMove  P_Active  P_Determined  P_Attentive  P_Inspired  P_Alert  \
# 0         -0.112509 -1.735667      0.112509     0.160128   -0.112509      0.0
# 1         -0.112509 -3.975237      0.112509     0.160128   -0.112509      0.0
# 2         -0.112509 -1.735667      0.112509     0.160128   -0.112509      0.0
# 3         -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 4         -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# ..              ...       ...           ...          ...         ...      ...
# 75        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 76        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 77        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 78        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 79        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
#
#     ...  P_Ashamed_  ControlLife_  BodyEnergy_  BodyRelax_  MindRelax_  \
# 0   ...         0.0           0.0    -1.676163   -2.380476    0.284747
# 1   ...         0.0           0.0     0.596601    0.420084    0.284747
# 2   ...         0.0           0.0    -1.676163   -2.380476    0.284747
# 3   ...         0.0           0.0    -1.676163    0.420084    0.284747
# 4   ...         0.0           0.0    -1.676163    0.420084    0.284747
# ..  ...         ...           ...          ...         ...         ...
# 75  ...         0.0           0.0    -1.676163    0.420084    0.284747
# 76  ...         0.0           0.0     0.596601    0.420084    0.284747
# 77  ...         0.0           0.0     0.596601    0.420084    0.284747
# 78  ...         0.0           0.0     0.596601    0.420084    0.284747
# 79  ...         0.0           0.0    -1.676163   -2.380476   -3.511885
#
#     SpatialSpan3_  SpatialSpan4_  SpatialSpan5_  GridA_secs_  GridB_secs_
# 0        0.229416      -0.273519      -1.662505     4.054276     3.936321
# 1        0.229416       0.677851      -3.055179    -0.099869    -0.081198
# 2        0.229416      -0.273519      -0.966168    -0.167015    -0.145093
# 3        0.229416      -1.224889       1.122843    -0.235814    -0.173425
# 4        0.229416      -2.176259       1.122843    -0.236837    -0.242645
# ..            ...            ...            ...          ...          ...
# 75       0.229416       0.677851       0.426506    -0.119494    -0.157161
# 76       0.229416       0.677851       1.122843    -0.246599    -0.267317
# 77       0.229416      -0.273519       1.122843     1.889929     1.787556
# 78      -2.064742       0.677851      -0.269831    -0.243537    -0.262229
# 79       0.229416       0.677851      -0.269831    -0.237218    -0.251327
#
# [80 rows x 48 columns]

# %%
# remove columns that end with _
# Identify columns to drop
cols_to_drop = [col for col in df.columns if col.endswith('_')]

# Drop the identified columns
df_cleaned = df.drop(columns=cols_to_drop)
df_cleaned.shape
# Out:
# (80, 24)

# %%
# add the lags, with a suffix of '_lag'
df_lag = fc.add_lag_columns(df_cleaned, lag_stub='_lag')
df_lag
# Out:
#     PainIntensity  PainControl  PainConcerned  PainAffectFunc  \
# 0       -0.165406     0.294884      -0.151717       -0.229416
# 1       -0.165406     0.294884      -0.151717       -0.229416
# 2       -0.165406     0.294884      -0.151717       -0.229416
# 3       -0.165406     0.294884      -0.151717       -0.229416
# 4       -0.165406     0.294884      -0.151717       -0.229416
# ..            ...          ...            ...             ...
# 74      -2.055755     0.294884      -0.151717       -0.229416
# 75      -2.055755     0.294884      -0.151717       -0.229416
# 76      -0.165406     0.294884      -0.151717       -0.229416
# 77      -0.165406     0.294884      -0.151717       -0.229416
# 78      -0.165406     0.294884      -0.151717       -0.229416
#
#     PainFearfulMove  P_Active  P_Determined  P_Attentive  P_Inspired  P_Alert  \
# 0         -0.112509 -3.975237      0.112509     0.160128   -0.112509      0.0
# 1         -0.112509 -1.735667      0.112509     0.160128   -0.112509      0.0
# 2         -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 3         -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 4         -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# ..              ...       ...           ...          ...         ...      ...
# 74        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 75        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 76        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 77        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
# 78        -0.112509  0.503903      0.112509     0.160128   -0.112509      0.0
#
#     ...  P_Ashamed_lag  ControlLife_lag  BodyEnergy_lag  BodyRelax_lag  \
# 0   ...            0.0              0.0        0.577350       0.420084
# 1   ...            0.0              0.0       -1.732051      -2.380476
# 2   ...            0.0              0.0       -1.732051       0.420084
# 3   ...            0.0              0.0       -1.732051       0.420084
# 4   ...            0.0              0.0        0.577350       0.420084
# ..  ...            ...              ...             ...            ...
# 74  ...            0.0              0.0       -1.732051       0.420084
# 75  ...            0.0              0.0        0.577350       0.420084
# 76  ...            0.0              0.0        0.577350       0.420084
# 77  ...            0.0              0.0        0.577350       0.420084
# 78  ...            0.0              0.0       -1.732051      -2.380476
#
#     MindRelax_lag  SpatialSpan3_lag  SpatialSpan4_lag  SpatialSpan5_lag  \
# 0        0.284747          0.229416          0.664411         -2.920630
# 1        0.284747          0.229416         -0.284747         -0.912174
# 2        0.284747          0.229416         -1.233905          1.096282
# 3        0.284747          0.229416         -2.183063          1.096282
# 4        0.284747          0.229416          0.664411         -1.581659
# ..            ...               ...               ...               ...
# 74       0.284747          0.229416          0.664411          0.426797
# 75       0.284747          0.229416          0.664411          1.096282
# 76       0.284747          0.229416         -0.284747          1.096282
# 77       0.284747         -2.064742          0.664411         -0.242688
# 78      -3.511885          0.229416          0.664411         -0.242688
#
#     GridA_secs_lag  GridB_secs_lag
# 0        -0.052046       -0.032113
# 1        -0.127481       -0.103354
# 2        -0.204772       -0.134944
# 3        -0.205921       -0.212122
# 4        -0.069697       -0.054554
# ..             ...             ...
# 74       -0.074094       -0.116810
# 75       -0.216889       -0.239632
# 76        2.183365        2.051512
# 77       -0.213448       -0.233958
# 78       -0.206350       -0.221803
#
# [79 rows x 48 columns]

# %%
# standardize the data
df_lag_std = fc.standardize_df_cols(df_lag)
df_lag_std
# Out:
#     PainIntensity  PainControl  PainConcerned  PainAffectFunc  \
# 0       -0.166478     0.296908      -0.152696        -0.23094
# 1       -0.166478     0.296908      -0.152696        -0.23094
# 2       -0.166478     0.296908      -0.152696        -0.23094
# 3       -0.166478     0.296908      -0.152696        -0.23094
# 4       -0.166478     0.296908      -0.152696        -0.23094
# ..            ...          ...            ...             ...
# 74      -2.045301     0.296908      -0.152696        -0.23094
# 75      -2.045301     0.296908      -0.152696        -0.23094
# 76      -0.166478     0.296908      -0.152696        -0.23094
# 77      -0.166478     0.296908      -0.152696        -0.23094
# 78      -0.166478     0.296908      -0.152696        -0.23094
#
#     PainFearfulMove  P_Active  P_Determined  P_Attentive  P_Inspired  P_Alert  \
# 0         -0.113228 -4.050119      0.113228     0.161165   -0.113228      0.0
# 1         -0.113228 -1.780903      0.113228     0.161165   -0.113228      0.0
# 2         -0.113228  0.488312      0.113228     0.161165   -0.113228      0.0
# 3         -0.113228  0.488312      0.113228     0.161165   -0.113228      0.0
# 4         -0.113228  0.488312      0.113228     0.161165   -0.113228      0.0
# ..              ...       ...           ...          ...         ...      ...
# 74        -0.113228  0.488312      0.113228     0.161165   -0.113228      0.0
# 75        -0.113228  0.488312      0.113228     0.161165   -0.113228      0.0
# 76        -0.113228  0.488312      0.113228     0.161165   -0.113228      0.0
# 77        -0.113228  0.488312      0.113228     0.161165   -0.113228      0.0
# 78        -0.113228  0.488312      0.113228     0.161165   -0.113228      0.0
#
#     ...  P_Ashamed_lag  ControlLife_lag  BodyEnergy_lag  BodyRelax_lag  \
# 0   ...            0.0              0.0        0.582223       0.402200
# 1   ...            0.0              0.0       -1.717556      -2.486326
# 2   ...            0.0              0.0       -1.717556       0.402200
# 3   ...            0.0              0.0       -1.717556       0.402200
# 4   ...            0.0              0.0        0.582223       0.402200
# ..  ...            ...              ...             ...            ...
# 74  ...            0.0              0.0       -1.717556       0.402200
# 75  ...            0.0              0.0        0.582223       0.402200
# 76  ...            0.0              0.0        0.582223       0.402200
# 77  ...            0.0              0.0        0.582223       0.402200
# 78  ...            0.0              0.0       -1.717556      -2.486326
#
#     MindRelax_lag  SpatialSpan3_lag  SpatialSpan4_lag  SpatialSpan5_lag  \
# 0        0.286691          0.230940          0.670478         -3.111857
# 1        0.286691          0.230940         -0.275375         -0.998648
# 2        0.286691          0.230940         -1.221229          1.114562
# 3        0.286691          0.230940         -2.167082          1.114562
# 4        0.286691          0.230940          0.670478         -1.703051
# ..            ...               ...               ...               ...
# 74       0.286691          0.230940          0.670478          0.410159
# 75       0.286691          0.230940          0.670478          1.114562
# 76       0.286691          0.230940         -0.275375          1.114562
# 77       0.286691         -2.049593          0.670478         -0.294244
# 78      -3.488075          0.230940          0.670478         -0.294244
#
#     GridA_secs_lag  GridB_secs_lag
# 0        -0.054213       -0.034771
# 1        -0.129193       -0.105589
# 2        -0.206018       -0.136990
# 3        -0.207160       -0.213710
# 4        -0.071757       -0.057078
# ..             ...             ...
# 74       -0.076128       -0.118964
# 75       -0.218062       -0.241055
# 76        2.167730        2.036463
# 77       -0.214642       -0.235416
# 78       -0.207586       -0.223333
#
# [79 rows x 48 columns]

# %%
# method to automatically create the knowledge for lag variables
def create_lag_knowledge(columns, lag_stub = '_'):
    """
    Create a lag knowledge structure based on the columns

    Sample structure
    
    knowledge = {'addtemporal': {
                            0: ['alcohol_bev_lag',
                                'TIB_lag',
                                'TST_lag',
                                'PANAS_PA_lag',
                                'PANAS_NA_lag',
                                'worry_scale_lag',
                                'PHQ9_lag'],
                            1: ['alcohol_bev',
                                'TIB',
                                'TST',
                                'PANAS_PA',
                                'PANAS_NA',
                                'worry_scale',
                                'PHQ9']
                            }
            }
    Args:
        columns (List): list of column names
        lag_stub (str, optional): lag stub suffix. Defaults to '_'.
    """
    
    # create the 1 list
    list_1 = [col for col in columns]
    # create the 0 list, the lagged variables
    list_0 = [col+lag_stub for col in columns]
    
    knowledge = {"addtemporal": {
                                    0: list_0,
                                    1: list_1
                                    }
                 }
    return knowledge

knowledge = create_lag_knowledge(df_cleaned.columns, lag_stub='_lag')
pass

# %%
knowledge = fc.create_lag_knowledge(df_cleaned.columns, lag_stub = '_lag')

# %%
# run model with run_model_search
result, graph = fc.run_model_search(df_lag_std, 
                             model = 'gfci',
                             score={'sem_bic': {'penalty_discount': 1.0}},
                             test={"fisher_z": {"alpha": .01}},
                             knowledge=knowledge
                             )
pass
# Out:
# Singularity encountered when scoring PainIntensity | P_Alert
# Singularity encountered when scoring PainIntensity | P_Afraid
# Singularity encountered when scoring PainIntensity | P_Nervous
# Singularity encountered when scoring PainIntensity | P_Hostile
# Singularity encountered when scoring PainIntensity | P_Ashamed
# Singularity encountered when scoring PainIntensity | ControlLife
# Singularity encountered when scoring PainIntensity | P_Alert_lag
# Singularity encountered when scoring PainIntensity | P_Afraid_lag
# Singularity encountered when scoring PainIntensity | P_Nervous_lag
# Singularity encountered when scoring PainIntensity | P_Hostile_lag
# Singularity encountered when scoring PainIntensity | P_Ashamed_lag
# Singularity encountered when scoring PainIntensity | ControlLife_lag
# Singularity encountered when scoring PainControl | P_Alert
# Singularity encountered when scoring PainControl | P_Afraid
# Singularity encountered when scoring PainControl | P_Nervous
# Singularity encountered when scoring PainControl | P_Hostile
# Singularity encountered when scoring PainControl | P_Ashamed
# Singularity encountered when scoring PainControl | ControlLife
# Singularity encountered when scoring PainControl | P_Alert_lag
# Singularity encountered when scoring PainControl | P_Afraid_lag
# Singularity encountered when scoring PainControl | P_Nervous_lag
# Singularity encountered when scoring PainControl | P_Hostile_lag
# Singularity encountered when scoring PainControl | P_Ashamed_lag
# Singularity encountered when scoring PainControl | ControlLife_lag
# Singularity encountered when scoring PainConcerned | P_Alert
# Singularity encountered when scoring PainConcerned | P_Afraid
# Singularity encountered when scoring PainConcerned | P_Nervous
# Singularity encountered when scoring PainConcerned | P_Hostile
# Singularity encountered when scoring PainConcerned | P_Ashamed
# Singularity encountered when scoring PainConcerned | ControlLife
# Singularity encountered when scoring PainConcerned | P_Alert_lag
# Singularity encountered when scoring PainConcerned | P_Afraid_lag
# Singularity encountered when scoring PainConcerned | P_Nervous_lag
# Singularity encountered when scoring PainConcerned | P_Hostile_lag
# Singularity encountered when scoring PainConcerned | P_Ashamed_lag
# Singularity encountered when scoring PainConcerned | ControlLife_lag
# Singularity encountered when scoring PainAffectFunc | P_Alert
# Singularity encountered when scoring PainAffectFunc | P_Afraid
# Singularity encountered when scoring PainAffectFunc | P_Nervous
# Singularity encountered when scoring PainAffectFunc | P_Hostile
# Singularity encountered when scoring PainAffectFunc | P_Ashamed
# Singularity encountered when scoring PainAffectFunc | ControlLife
# Singularity encountered when scoring PainAffectFunc | P_Alert_lag
# Singularity encountered when scoring PainAffectFunc | P_Afraid_lag
# Singularity encountered when scoring PainAffectFunc | P_Nervous_lag
# Singularity encountered when scoring PainAffectFunc | P_Hostile_lag
# Singularity encountered when scoring PainAffectFunc | P_Ashamed_lag
# Singularity encountered when scoring PainAffectFunc | ControlLife_lag
# Singularity encountered when scoring PainFearfulMove | P_Alert
# Singularity encountered when scoring PainFearfulMove | P_Afraid
# Singularity encountered when scoring PainFearfulMove | P_Nervous
# Singularity encountered when scoring PainFearfulMove | P_Hostile
# Singularity encountered when scoring PainFearfulMove | P_Ashamed
# Singularity encountered when scoring PainFearfulMove | ControlLife
# Singularity encountered when scoring PainFearfulMove | P_Alert_lag
# Singularity encountered when scoring PainFearfulMove | P_Afraid_lag
# Singularity encountered when scoring PainFearfulMove | P_Nervous_lag
# Singularity encountered when scoring PainFearfulMove | P_Hostile_lag
# Singularity encountered when scoring PainFearfulMove | P_Ashamed_lag
# Singularity encountered when scoring PainFearfulMove | ControlLife_lag
# Singularity encountered when scoring P_Active | P_Alert
# Singularity encountered when scoring P_Active | P_Afraid
# Singularity encountered when scoring P_Active | P_Nervous
# Singularity encountered when scoring P_Active | P_Hostile
# Singularity encountered when scoring P_Active | P_Ashamed
# Singularity encountered when scoring P_Active | ControlLife
# Singularity encountered when scoring P_Active | P_Alert_lag
# Singularity encountered when scoring P_Active | P_Afraid_lag
# Singularity encountered when scoring P_Active | P_Nervous_lag
# Singularity encountered when scoring P_Active | P_Hostile_lag
# Singularity encountered when scoring P_Active | P_Ashamed_lag
# Singularity encountered when scoring P_Active | ControlLife_lag
# Singularity encountered when scoring P_Determined | P_Alert
# Singularity encountered when scoring P_Determined | P_Afraid
# Singularity encountered when scoring P_Determined | P_Nervous
# Singularity encountered when scoring P_Determined | P_Hostile
# Singularity encountered when scoring P_Determined | P_Ashamed
# Singularity encountered when scoring P_Determined | ControlLife
# Singularity encountered when scoring P_Determined | P_Alert_lag
# Singularity encountered when scoring P_Determined | P_Afraid_lag
# Singularity encountered when scoring P_Determined | P_Nervous_lag
# Singularity encountered when scoring P_Determined | P_Hostile_lag
# Singularity encountered when scoring P_Determined | P_Ashamed_lag
# Singularity encountered when scoring P_Determined | ControlLife_lag
# Singularity encountered when scoring P_Attentive | P_Alert
# Singularity encountered when scoring P_Attentive | P_Afraid
# Singularity encountered when scoring P_Attentive | P_Nervous
# Singularity encountered when scoring P_Attentive | P_Hostile
# Singularity encountered when scoring P_Attentive | P_Ashamed
# Singularity encountered when scoring P_Attentive | ControlLife
# Singularity encountered when scoring P_Attentive | P_Alert_lag
# Singularity encountered when scoring P_Attentive | P_Afraid_lag
# Singularity encountered when scoring P_Attentive | P_Nervous_lag
# Singularity encountered when scoring P_Attentive | P_Hostile_lag
# Singularity encountered when scoring P_Attentive | P_Ashamed_lag
# Singularity encountered when scoring P_Attentive | ControlLife_lag
# Singularity encountered when scoring P_Inspired | P_Alert
# Singularity encountered when scoring P_Inspired | P_Afraid
# Singularity encountered when scoring P_Inspired | P_Nervous
# Singularity encountered when scoring P_Inspired | P_Hostile
# Singularity encountered when scoring P_Inspired | P_Ashamed
# Singularity encountered when scoring P_Inspired | ControlLife
# Singularity encountered when scoring P_Inspired | P_Alert_lag
# Singularity encountered when scoring P_Inspired | P_Afraid_lag
# Singularity encountered when scoring P_Inspired | P_Nervous_lag
# Singularity encountered when scoring P_Inspired | P_Hostile_lag
# Singularity encountered when scoring P_Inspired | P_Ashamed_lag
# Singularity encountered when scoring P_Inspired | ControlLife_lag
# Singularity encountered when scoring P_Alert | P_Afraid
# Singularity encountered when scoring P_Alert | P_Nervous
# Singularity encountered when scoring P_Alert | P_Hostile
# Singularity encountered when scoring P_Alert | P_Ashamed
# Singularity encountered when scoring P_Alert | ControlLife
# Singularity encountered when scoring P_Alert | P_Alert_lag
# Singularity encountered when scoring P_Alert | P_Afraid_lag
# Singularity encountered when scoring P_Alert | P_Nervous_lag
# Singularity encountered when scoring P_Alert | P_Hostile_lag
# Singularity encountered when scoring P_Alert | P_Ashamed_lag
# Singularity encountered when scoring P_Alert | ControlLife_lag
# Singularity encountered when scoring P_Afraid | P_Nervous
# Singularity encountered when scoring P_Afraid | P_Hostile
# Singularity encountered when scoring P_Afraid | P_Ashamed
# Singularity encountered when scoring P_Afraid | ControlLife
# Singularity encountered when scoring P_Afraid | P_Alert_lag
# Singularity encountered when scoring P_Afraid | P_Afraid_lag
# Singularity encountered when scoring P_Afraid | P_Nervous_lag
# Singularity encountered when scoring P_Afraid | P_Hostile_lag
# Singularity encountered when scoring P_Afraid | P_Ashamed_lag
# Singularity encountered when scoring P_Afraid | ControlLife_lag
# Singularity encountered when scoring P_Nervous | P_Hostile
# Singularity encountered when scoring P_Nervous | P_Ashamed
# Singularity encountered when scoring P_Nervous | ControlLife
# Singularity encountered when scoring P_Nervous | P_Alert_lag
# Singularity encountered when scoring P_Nervous | P_Afraid_lag
# Singularity encountered when scoring P_Nervous | P_Nervous_lag
# Singularity encountered when scoring P_Nervous | P_Hostile_lag
# Singularity encountered when scoring P_Nervous | P_Ashamed_lag
# Singularity encountered when scoring P_Nervous | ControlLife_lag
# Singularity encountered when scoring P_upset | P_Hostile
# Singularity encountered when scoring P_upset | P_Ashamed
# Singularity encountered when scoring P_upset | ControlLife
# Singularity encountered when scoring P_upset | P_Alert_lag
# Singularity encountered when scoring P_upset | P_Afraid_lag
# Singularity encountered when scoring P_upset | P_Nervous_lag
# Singularity encountered when scoring P_upset | P_Hostile_lag
# Singularity encountered when scoring P_upset | P_Ashamed_lag
# Singularity encountered when scoring P_upset | ControlLife_lag
# Singularity encountered when scoring P_Hostile | P_Ashamed
# Singularity encountered when scoring P_Hostile | ControlLife
# Singularity encountered when scoring P_Hostile | P_Alert_lag
# Singularity encountered when scoring P_Hostile | P_Afraid_lag
# Singularity encountered when scoring P_Hostile | P_Nervous_lag
# Singularity encountered when scoring P_Hostile | P_Hostile_lag
# Singularity encountered when scoring P_Hostile | P_Ashamed_lag
# Singularity encountered when scoring P_Hostile | ControlLife_lag
# Singularity encountered when scoring P_Ashamed | ControlLife
# Singularity encountered when scoring P_Ashamed | P_Alert_lag
# Singularity encountered when scoring P_Ashamed | P_Afraid_lag
# Singularity encountered when scoring P_Ashamed | P_Nervous_lag
# Singularity encountered when scoring P_Ashamed | P_Hostile_lag
# Singularity encountered when scoring P_Ashamed | P_Ashamed_lag
# Singularity encountered when scoring P_Ashamed | ControlLife_lag
# Singularity encountered when scoring ControlLife | P_Alert_lag
# Singularity encountered when scoring ControlLife | P_Afraid_lag
# Singularity encountered when scoring ControlLife | P_Nervous_lag
# Singularity encountered when scoring ControlLife | P_Hostile_lag
# Singularity encountered when scoring ControlLife | P_Ashamed_lag
# Singularity encountered when scoring ControlLife | ControlLife_lag
# Singularity encountered when scoring BodyEnergy | P_Alert_lag
# Singularity encountered when scoring BodyEnergy | P_Afraid_lag
# Singularity encountered when scoring BodyEnergy | P_Nervous_lag
# Singularity encountered when scoring BodyEnergy | P_Hostile_lag
# Singularity encountered when scoring BodyEnergy | P_Ashamed_lag
# Singularity encountered when scoring BodyEnergy | ControlLife_lag
# Singularity encountered when scoring BodyRelax | P_Alert_lag
# Singularity encountered when scoring BodyRelax | P_Afraid_lag
# Singularity encountered when scoring BodyRelax | P_Nervous_lag
# Singularity encountered when scoring BodyRelax | P_Hostile_lag
# Singularity encountered when scoring BodyRelax | P_Ashamed_lag
# Singularity encountered when scoring BodyRelax | ControlLife_lag
# Singularity encountered when scoring MindRelax | P_Alert_lag
# Singularity encountered when scoring MindRelax | P_Afraid_lag
# Singularity encountered when scoring MindRelax | P_Nervous_lag
# Singularity encountered when scoring MindRelax | P_Hostile_lag
# Singularity encountered when scoring MindRelax | P_Ashamed_lag
# Singularity encountered when scoring MindRelax | ControlLife_lag
# Singularity encountered when scoring SpatialSpan3 | P_Alert_lag
# Singularity encountered when scoring SpatialSpan3 | P_Afraid_lag
# Singularity encountered when scoring SpatialSpan3 | P_Nervous_lag
# Singularity encountered when scoring SpatialSpan3 | P_Hostile_lag
# Singularity encountered when scoring SpatialSpan3 | P_Ashamed_lag
# Singularity encountered when scoring SpatialSpan3 | ControlLife_lag
# Singularity encountered when scoring SpatialSpan4 | P_Alert_lag
# Singularity encountered when scoring SpatialSpan4 | P_Afraid_lag
# Singularity encountered when scoring SpatialSpan4 | P_Nervous_lag
# Singularity encountered when scoring SpatialSpan4 | P_Hostile_lag
# Singularity encountered when scoring SpatialSpan4 | P_Ashamed_lag
# Singularity encountered when scoring SpatialSpan4 | ControlLife_lag
# Singularity encountered when scoring SpatialSpan5 | P_Alert_lag
# Singularity encountered when scoring SpatialSpan5 | P_Afraid_lag
# Singularity encountered when scoring SpatialSpan5 | P_Nervous_lag
# Singularity encountered when scoring SpatialSpan5 | P_Hostile_lag
# Singularity encountered when scoring SpatialSpan5 | P_Ashamed_lag
# Singularity encountered when scoring SpatialSpan5 | ControlLife_lag
# Singularity encountered when scoring GridA_secs | P_Alert_lag
# Singularity encountered when scoring GridA_secs | P_Afraid_lag
# Singularity encountered when scoring GridA_secs | P_Nervous_lag
# Singularity encountered when scoring GridA_secs | P_Hostile_lag
# Singularity encountered when scoring GridA_secs | P_Ashamed_lag
# Singularity encountered when scoring GridA_secs | ControlLife_lag
# Singularity encountered when scoring GridB_secs | P_Alert_lag
# Singularity encountered when scoring GridB_secs | P_Afraid_lag
# Singularity encountered when scoring GridB_secs | P_Nervous_lag
# Singularity encountered when scoring GridB_secs | P_Hostile_lag
# Singularity encountered when scoring GridB_secs | P_Ashamed_lag
# Singularity encountered when scoring GridB_secs | ControlLife_lag
# Singularity encountered when scoring PainIntensity_lag | P_Alert_lag
# Singularity encountered when scoring PainIntensity_lag | P_Afraid_lag
# Singularity encountered when scoring PainIntensity_lag | P_Nervous_lag
# Singularity encountered when scoring PainIntensity_lag | P_Hostile_lag
# Singularity encountered when scoring PainIntensity_lag | P_Ashamed_lag
# Singularity encountered when scoring PainIntensity_lag | ControlLife_lag
# Singularity encountered when scoring PainControl_lag | P_Alert_lag
# Singularity encountered when scoring PainControl_lag | P_Afraid_lag
# Singularity encountered when scoring PainControl_lag | P_Nervous_lag
# Singularity encountered when scoring PainControl_lag | P_Hostile_lag
# Singularity encountered when scoring PainControl_lag | P_Ashamed_lag
# Singularity encountered when scoring PainControl_lag | ControlLife_lag
# Singularity encountered when scoring PainConcerned_lag | P_Alert_lag
# Singularity encountered when scoring PainConcerned_lag | P_Afraid_lag
# Singularity encountered when scoring PainConcerned_lag | P_Nervous_lag
# Singularity encountered when scoring PainConcerned_lag | P_Hostile_lag
# Singularity encountered when scoring PainConcerned_lag | P_Ashamed_lag
# Singularity encountered when scoring PainConcerned_lag | ControlLife_lag
# Singularity encountered when scoring PainAffectFunc_lag | P_Alert_lag
# Singularity encountered when scoring PainAffectFunc_lag | P_Afraid_lag
# Singularity encountered when scoring PainAffectFunc_lag | P_Nervous_lag
# Singularity encountered when scoring PainAffectFunc_lag | P_Hostile_lag
# Singularity encountered when scoring PainAffectFunc_lag | P_Ashamed_lag
# Singularity encountered when scoring PainAffectFunc_lag | ControlLife_lag
# Singularity encountered when scoring PainFearfulMove_lag | P_Alert_lag
# Singularity encountered when scoring PainFearfulMove_lag | P_Afraid_lag
# Singularity encountered when scoring PainFearfulMove_lag | P_Nervous_lag
# Singularity encountered when scoring PainFearfulMove_lag | P_Hostile_lag
# Singularity encountered when scoring PainFearfulMove_lag | P_Ashamed_lag
# Singularity encountered when scoring PainFearfulMove_lag | ControlLife_lag
# Singularity encountered when scoring P_Active_lag | P_Alert_lag
# Singularity encountered when scoring P_Active_lag | P_Afraid_lag
# Singularity encountered when scoring P_Active_lag | P_Nervous_lag
# Singularity encountered when scoring P_Active_lag | P_Hostile_lag
# Singularity encountered when scoring P_Active_lag | P_Ashamed_lag
# Singularity encountered when scoring P_Active_lag | ControlLife_lag
# Singularity encountered when scoring P_Determined_lag | P_Alert_lag
# Singularity encountered when scoring P_Determined_lag | P_Afraid_lag
# Singularity encountered when scoring P_Determined_lag | P_Nervous_lag
# Singularity encountered when scoring P_Determined_lag | P_Hostile_lag
# Singularity encountered when scoring P_Determined_lag | P_Ashamed_lag
# Singularity encountered when scoring P_Determined_lag | ControlLife_lag
# Singularity encountered when scoring P_Attentive_lag | P_Alert_lag
# Singularity encountered when scoring P_Attentive_lag | P_Afraid_lag
# Singularity encountered when scoring P_Attentive_lag | P_Nervous_lag
# Singularity encountered when scoring P_Attentive_lag | P_Hostile_lag
# Singularity encountered when scoring P_Attentive_lag | P_Ashamed_lag
# Singularity encountered when scoring P_Attentive_lag | ControlLife_lag
# Singularity encountered when scoring P_Inspired_lag | P_Alert_lag
# Singularity encountered when scoring P_Inspired_lag | P_Afraid_lag
# Singularity encountered when scoring P_Inspired_lag | P_Nervous_lag
# Singularity encountered when scoring P_Inspired_lag | P_Hostile_lag
# Singularity encountered when scoring P_Inspired_lag | P_Ashamed_lag
# Singularity encountered when scoring P_Inspired_lag | ControlLife_lag
# Singularity encountered when scoring P_Alert_lag | P_Afraid_lag
# Singularity encountered when scoring P_Alert_lag | P_Nervous_lag
# Singularity encountered when scoring P_Alert_lag | P_Hostile_lag
# Singularity encountered when scoring P_Alert_lag | P_Ashamed_lag
# Singularity encountered when scoring P_Alert_lag | ControlLife_lag
# Singularity encountered when scoring P_Afraid_lag | P_Nervous_lag
# Singularity encountered when scoring P_Afraid_lag | P_Hostile_lag
# Singularity encountered when scoring P_Afraid_lag | P_Ashamed_lag
# Singularity encountered when scoring P_Afraid_lag | ControlLife_lag
# Singularity encountered when scoring P_Nervous_lag | P_Hostile_lag
# Singularity encountered when scoring P_Nervous_lag | P_Ashamed_lag
# Singularity encountered when scoring P_Nervous_lag | ControlLife_lag
# Singularity encountered when scoring P_upset_lag | P_Hostile_lag
# Singularity encountered when scoring P_upset_lag | P_Ashamed_lag
# Singularity encountered when scoring P_upset_lag | ControlLife_lag
# Singularity encountered when scoring P_Hostile_lag | P_Ashamed_lag
# Singularity encountered when scoring P_Hostile_lag | ControlLife_lag
# Singularity encountered when scoring P_Ashamed_lag | ControlLife_lag
# Singularity encountered when scoring P_Attentive | P_Determined, PainFearfulMove_lag
# Singularity encountered when scoring PainConcerned | PainAffectFunc, P_Determined, P_Attentive, BodyRelax, PainFearfulMove_lag, P_Inspired_lag
# Singularity encountered when scoring GridB_secs | P_Determined, PainIntensity_lag, PainFearfulMove_lag
# Caught a Java error during GFCI execution: java.lang.RuntimeException: Singular matrix encountered for test: P_Determined _||_ P_Attentive | PainFearfulMove_lag
# This often means a singular matrix was encountered.

# %%
graph.show_graph()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 graph.show_graph()
#
# AttributeError: 'NoneType' object has no attribute 'show_graph'
