# %% [markdown]
# Code to demonstrate basic FastCDA capabilities in a Jupyter notebook.

# %%
from fastcda import FastCDA
from dgraph_flex import DgraphFlex
import semopy
import pprint as pp

# create  an instance of FastCDA
# the default version is 7.6.8 of the tetrad jar
fc = FastCDA(tetrad_version="7.6.8")

# %% [markdown]
# ###  *Reading in data*
#
# For this demo, we are going to use a sample ema dataset that is built into
# the fastcda package.
#
# To read in your own csv data file "mydata.csv" you would
# use the pandas package, a very powerful package for working
# with dataframes.
#
# Here is the code:
# ```
# import pandas as pd
#
# df = pd.read_csv("mydata.csv")
#
# ```

# %%
# read in the sample ema dataset and view it
df = fc.getEMAData()

df
# Out:
#      alcohol_bev    TIB       TST  PANAS_PA  PANAS_NA  worry_scale  PHQ9
# 0            1.0   9.00  7.333333      44.0      13.0          8.0   0.0
# 1            0.0  10.25  8.750000      40.0      12.0         14.0   0.0
# 2            1.0   8.50  7.166667      39.0      12.0         15.0   0.0
# 3            1.0   8.75  8.083333      39.0      12.0         12.0   0.0
# 4            1.0   8.25  6.666667      38.0      13.0         15.0   0.0
# ..           ...    ...       ...       ...       ...          ...   ...
# 636          4.0   8.75  7.916667      29.0      12.0         17.0   3.0
# 637          4.0   8.50  7.666667      31.0      12.0         17.0   4.0
# 638          3.0   8.50  7.583333      33.0      13.0         17.0   3.0
# 639          3.0   9.00  8.166667      31.0      12.0         19.0   2.0
# 640          4.0   8.25  7.416667      31.0      13.0         17.0   1.0
#
# [641 rows x 7 columns]

# %%
# add the lags, with a suffix of '_lag'
lag_stub = '_lag'
df_lag = fc.add_lag_columns(df, lag_stub=lag_stub)
df_lag
# Out:
#      alcohol_bev    TIB       TST  PANAS_PA  PANAS_NA  worry_scale  PHQ9  \
# 0            0.0  10.25  8.750000      40.0      12.0         14.0   0.0
# 1            1.0   8.50  7.166667      39.0      12.0         15.0   0.0
# 2            1.0   8.75  8.083333      39.0      12.0         12.0   0.0
# 3            1.0   8.25  6.666667      38.0      13.0         15.0   0.0
# 4            0.0   8.25  7.416667      37.0      12.0         16.0   0.0
# ..           ...    ...       ...       ...       ...          ...   ...
# 635          4.0   8.75  7.916667      29.0      12.0         17.0   3.0
# 636          4.0   8.50  7.666667      31.0      12.0         17.0   4.0
# 637          3.0   8.50  7.583333      33.0      13.0         17.0   3.0
# 638          3.0   9.00  8.166667      31.0      12.0         19.0   2.0
# 639          4.0   8.25  7.416667      31.0      13.0         17.0   1.0
#
#      alcohol_bev_lag  TIB_lag   TST_lag  PANAS_PA_lag  PANAS_NA_lag  \
# 0                1.0     9.00  7.333333          44.0          13.0
# 1                0.0    10.25  8.750000          40.0          12.0
# 2                1.0     8.50  7.166667          39.0          12.0
# 3                1.0     8.75  8.083333          39.0          12.0
# 4                1.0     8.25  6.666667          38.0          13.0
# ..               ...      ...       ...           ...           ...
# 635              6.0     7.00  6.166667          31.0          15.0
# 636              4.0     8.75  7.916667          29.0          12.0
# 637              4.0     8.50  7.666667          31.0          12.0
# 638              3.0     8.50  7.583333          33.0          13.0
# 639              3.0     9.00  8.166667          31.0          12.0
#
#      worry_scale_lag  PHQ9_lag
# 0                8.0       0.0
# 1               14.0       0.0
# 2               15.0       0.0
# 3               12.0       0.0
# 4               15.0       0.0
# ..               ...       ...
# 635             18.0       3.0
# 636             17.0       3.0
# 637             17.0       4.0
# 638             17.0       3.0
# 639             19.0       2.0
#
# [640 rows x 14 columns]

# %%
# standardize the data
df_lag_std = fc.standardize_df_cols(df_lag)
df_lag_std
# Out:
#      alcohol_bev       TIB       TST  PANAS_PA  PANAS_NA  worry_scale  \
# 0      -0.720086  0.945596  0.714807  1.403653 -0.442144    -1.025409
# 1      -0.048041 -0.349371 -0.463029  1.300809 -0.442144    -0.866815
# 2      -0.048041 -0.164376  0.218876  1.300809 -0.442144    -1.342597
# 3      -0.048041 -0.534367 -0.834977  1.197966 -0.237832    -0.866815
# 4      -0.720086 -0.534367 -0.277055  1.095122 -0.442144    -0.708221
# ..           ...       ...       ...       ...       ...          ...
# 635     1.968095 -0.164376  0.094893  0.272375 -0.442144    -0.549627
# 636     1.968095 -0.349371 -0.091081  0.478062 -0.442144    -0.549627
# 637     1.296050 -0.349371 -0.153072  0.683748 -0.237832    -0.549627
# 638     1.296050  0.020619  0.280867  0.478062 -0.442144    -0.232439
# 639     1.968095 -0.534367 -0.277055  0.478062 -0.237832    -0.549627
#
#          PHQ9  alcohol_bev_lag   TIB_lag   TST_lag  PANAS_PA_lag  \
# 0   -0.961531        -0.045027  0.019757 -0.338939      1.808615
# 1   -0.961531        -0.719118  0.944940  0.714883      1.398222
# 2   -0.961531        -0.045027 -0.350317 -0.462918      1.295624
# 3   -0.961531        -0.045027 -0.165280  0.218966      1.295624
# 4   -0.961531        -0.045027 -0.535353 -0.834856      1.193025
# ..        ...              ...       ...       ...           ...
# 635  0.053947         3.325425 -1.460537 -1.206793      0.474838
# 636  0.392440         1.977244 -0.165280  0.094987      0.269641
# 637  0.053947         1.977244 -0.350317 -0.090981      0.474838
# 638 -0.284546         1.303154 -0.350317 -0.152971      0.680034
# 639 -0.623038         1.303154  0.019757  0.280956      0.474838
#
#      PANAS_NA_lag  worry_scale_lag  PHQ9_lag
# 0       -0.237832        -1.969207 -0.960600
# 1       -0.442144        -1.020311 -0.960600
# 2       -0.442144        -0.862161 -0.960600
# 3       -0.442144        -1.336610 -0.960600
# 4       -0.237832        -0.862161 -0.960600
# ..            ...              ...       ...
# 635      0.170792        -0.387713  0.054453
# 636     -0.442144        -0.545863  0.054453
# 637     -0.442144        -0.545863  0.392805
# 638     -0.237832        -0.545863  0.054453
# 639     -0.442144        -0.229564 -0.283898
#
# [640 rows x 14 columns]

# %%
# lets get the dataframe col names
cols = df.columns
cols
# Out:
# Index(['alcohol_bev', 'TIB', 'TST', 'PANAS_PA', 'PANAS_NA', 'worry_scale',
#        'PHQ9'],
#       dtype='object')

# %%
# Create the knowledge prior content for temporal
# order. The lag variables can only be parents of the non
# lag variables

knowledge = {'addtemporal': {
                            0: [col + lag_stub for col in cols],
                            1: [col for col in cols]
                            }
            }
knowledge
# Out:
# {'addtemporal': {0: ['alcohol_bev_lag',
#    'TIB_lag',
#    'TST_lag',
#    'PANAS_PA_lag',
#    'PANAS_NA_lag',
#    'worry_scale_lag',
#    'PHQ9_lag'],
#   1: ['alcohol_bev',
#    'TIB',
#    'TST',
#    'PANAS_PA',
#    'PANAS_NA',
#    'worry_scale',
#    'PHQ9']}}

# %%
# run model with run_model_search
result, graph = fc.run_model_search(df_lag_std, 
                             model = 'gfci',
                             score={'sem_bic': {'penalty_discount': 1.0}},
                             test={"fisher_z": {"alpha": .01}},
                             knowledge=knowledge
                             )
# Out:
# Mar 11, 2026 12:48:48 PM java.util.prefs.FileSystemPreferences$6 run
# WARNING: Prefs file removed in background /home/kolim/.java/.userPrefs/prefs.xml

# %%
graph.show_graph()

# %%
print(result)
# Out:
# {'edges': ['PHQ9 --> PANAS_NA', 'worry_scale_lag --> worry_scale', 'TIB --> PANAS_NA', 'worry_scale_lag --> PANAS_PA_lag', 'worry_scale --> TST', 'PHQ9 <-> PANAS_NA_lag', 'worry_scale_lag --> TST_lag', 'worry_scale --> PANAS_PA', 'PANAS_NA <-> PANAS_NA_lag', 'TIB_lag o-> TST_lag', 'PANAS_PA_lag --> PHQ9_lag', 'worry_scale_lag --> alcohol_bev_lag', 'TIB <-> TST', 'alcohol_bev_lag --> alcohol_bev', 'PANAS_PA <-> PHQ9', 'TIB_lag o-> TIB', 'PANAS_NA_lag --> worry_scale_lag', 'PANAS_PA_lag --> PANAS_PA', 'PHQ9_lag <-> PANAS_NA_lag', 'PHQ9_lag --> PHQ9', 'PANAS_NA --> worry_scale', 'TST_lag --> TST'], 'cda_output': 'Graph Nodes:
# alcohol_bev;TIB;TST;PANAS_PA;PANAS_NA;worry_scale;PHQ9;alcohol_bev_lag;TIB_lag;TST_lag;PANAS_PA_lag;PANAS_NA_lag;worry_scale_lag;PHQ9_lag
#
# Graph Edges:
# 1. PANAS_NA <-> PANAS_NA_lag
# 2. PANAS_NA --> worry_scale
# 3. PANAS_NA_lag --> worry_scale_lag
# 4. PANAS_PA <-> PHQ9
# 5. PANAS_PA_lag --> PANAS_PA
# 6. PANAS_PA_lag --> PHQ9_lag
# 7. PHQ9 --> PANAS_NA
# 8. PHQ9 <-> PANAS_NA_lag
# 9. PHQ9_lag <-> PANAS_NA_lag
# 10. PHQ9_lag --> PHQ9
# 11. TIB --> PANAS_NA
# 12. TIB <-> TST
# 13. TIB_lag o-> TIB
# 14. TIB_lag o-> TST_lag
# 15. TST_lag --> TST
# 16. alcohol_bev_lag --> alcohol_bev
# 17. worry_scale --> PANAS_PA
# 18. worry_scale --> TST
# 19. worry_scale_lag --> PANAS_PA_lag
# 20. worry_scale_lag --> TST_lag
# 21. worry_scale_lag --> alcohol_bev_lag
# 22. worry_scale_lag --> worry_scale
#
# Graph Attributes:
# Score: 3172.922856
#
# Graph Node Attributes:
# Score: [alcohol_bev: 172.94452149162532;TIB: 80.92073574694803;TST: 337.35629327206647;PANAS_PA: 546.9471860766366;PANAS_NA: 459.71743626666307;worry_scale: 423.8024490534349;PHQ9: 442.9000733489483;alcohol_bev_lag: 3.6698422066051153;TIB_lag: 1.723236192684137;TST_lag: 294.5558826078536;PANAS_PA_lag: 74.61594807720329;PANAS_NA_lag: -0.5136096660416677;worry_scale_lag: 59.51212031721944;PHQ9_lag: 274.7707411504264]
# ', 'sem_results': {'opt_res': SolverResult(fun=np.float64(2.6568688907198066), success=np.True_, n_it=20, x=array([ 0.7358556 , -0.12627811,  0.81313101, -0.1057533 ,  0.36763655,
#         0.07701542,  0.40211943,  0.12753635,  0.77286687,  0.06801705,
#         0.87025564, -0.47851176,  0.15103913,  0.65114762,  0.48215695,
#        -0.42324649,  0.86051955,  0.44168914,  0.19615389,  0.86489518,
#         0.25923907,  0.77097566,  0.76752973,  0.82645235,  0.38982578,
#         0.57563341,  0.9772168 ,  0.26024495,  0.82067797]), message='Optimization terminated successfully', name_method='SLSQP', name_obj='MLW'), 'estimates':                lval  op             rval  Estimate  Std. Err    z-value  \
# 0          PANAS_NA   ~             PHQ9  0.735856  0.026275  28.006291
# 1          PANAS_NA   ~              TIB -0.126278  0.026271  -4.806773
# 2       worry_scale   ~  worry_scale_lag  0.813131  0.020301  40.053720
# 3       worry_scale   ~         PANAS_NA -0.105753  0.020302  -5.208945
# 4      PANAS_PA_lag   ~  worry_scale_lag  0.367637  0.036765   9.999735
# 5           TST_lag   ~  worry_scale_lag  0.127536  0.024719   5.159344
# 6           TST_lag   ~          TIB_lag  0.772867  0.024718  31.267101
# 7          PHQ9_lag   ~     PANAS_PA_lag -0.478512  0.034708 -13.786954
# 8   alcohol_bev_lag   ~  worry_scale_lag  0.151039  0.039079   3.864965
# 9               TIB   ~          TIB_lag  0.482157  0.034632  13.922420
# 10  worry_scale_lag   ~     PANAS_NA_lag -0.423246  0.035809 -11.819686
# 11             PHQ9   ~         PHQ9_lag  0.860520  0.020127  42.755388
# 12              TST   ~      worry_scale  0.077015  0.037234   2.068395
# 13              TST   ~          TST_lag  0.402119  0.036079  11.145565
# 14         PANAS_PA   ~      worry_scale  0.068017  0.019072   3.566367
# 15         PANAS_PA   ~     PANAS_PA_lag  0.870256  0.018610  46.761946
# 16      alcohol_bev   ~  alcohol_bev_lag  0.651148  0.029990  21.712109
# 17         PANAS_NA  ~~         PANAS_NA  0.441689  0.024691  17.888544
# 18     PANAS_PA_lag  ~~     PANAS_PA_lag  0.864895  0.048349  17.888544
# 19             PHQ9  ~~             PHQ9  0.259239  0.014492  17.888544
# 20         PHQ9_lag  ~~         PHQ9_lag  0.770976  0.043099  17.888544
# 21              TIB  ~~              TIB  0.767530  0.042906  17.888544
# 22          TST_lag  ~~          TST_lag  0.389826  0.021792  17.888544
# 23  alcohol_bev_lag  ~~  alcohol_bev_lag  0.977217  0.054628  17.888544
# 24      worry_scale  ~~      worry_scale  0.260245  0.014548  17.888544
# 25  worry_scale_lag  ~~  worry_scale_lag  0.820678  0.045877  17.888544
# 26         PANAS_PA  ~~         PANAS_PA  0.196154  0.010965  17.888544
# 27              TST  ~~              TST  0.826452  0.046200  17.888544
# 28      alcohol_bev  ~~      alcohol_bev  0.575633  0.032179  17.888544
#
#          p-value
# 0   0.000000e+00
# 1   1.533864e-06
# 2   0.000000e+00
# 3   1.899176e-07
# 4   0.000000e+00
# 5   2.478161e-07
# 6   0.000000e+00
# 7   0.000000e+00
# 8   1.111052e-04
# 9   0.000000e+00
# 10  0.000000e+00
# 11  0.000000e+00
# 12  3.860290e-02
# 13  0.000000e+00
# 14  3.619639e-04
# 15  0.000000e+00
# 16  0.000000e+00
# 17  0.000000e+00
# 18  0.000000e+00
# 19  0.000000e+00
# 20  0.000000e+00
# 21  0.000000e+00
# 22  0.000000e+00
# 23  0.000000e+00
# 24  0.000000e+00
# 25  0.000000e+00
# 26  0.000000e+00
# 27  0.000000e+00
# 28  0.000000e+00  , 'estimatesDict': [{'dest': 'PANAS_NA', 'op': '~', 'src': 'PHQ9', 'Estimate': 0.7358555978838115, 'Std. Err': 0.026274653946192283, 'z-value': 28.0062907531631, 'p-value': 0.0}, {'dest': 'PANAS_NA', 'op': '~', 'src': 'TIB', 'Estimate': -0.1262781083467664, 'Std. Err': 0.026270872631111518, 'z-value': -4.806772508668541, 'p-value': 1.5338635888095808e-06}, {'dest': 'worry_scale', 'op': '~', 'src': 'worry_scale_lag', 'Estimate': 0.8131310099228454, 'Std. Err': 0.020301010828977072, 'z-value': 40.05372031633775, 'p-value': 0.0}, {'dest': 'worry_scale', 'op': '~', 'src': 'PANAS_NA', 'Estimate': -0.10575330067710305, 'Std. Err': 0.02030225031277975, 'z-value': -5.20894477423151, 'p-value': 1.8991762540387924e-07}, {'dest': 'PANAS_PA_lag', 'op': '~', 'src': 'worry_scale_lag', 'Estimate': 0.3676365492803433, 'Std. Err': 0.03676462975122097, 'z-value': 9.999734847272173, 'p-value': 0.0}, {'dest': 'TST_lag', 'op': '~', 'src': 'worry_scale_lag', 'Estimate': 0.12753634632050453, 'Std. Err': 0.024719486950639896, 'z-value': 5.159344389712091, 'p-value': 2.478160960883713e-07}, {'dest': 'TST_lag', 'op': '~', 'src': 'TIB_lag', 'Estimate': 0.7728668668681222, 'Std. Err': 0.02471821341910694, 'z-value': 31.26710064892621, 'p-value': 0.0}, {'dest': 'PHQ9_lag', 'op': '~', 'src': 'PANAS_PA_lag', 'Estimate': -0.4785117602994812, 'Std. Err': 0.034707576773774784, 'z-value': -13.786953880550374, 'p-value': 0.0}, {'dest': 'alcohol_bev_lag', 'op': '~', 'src': 'worry_scale_lag', 'Estimate': 0.15103912869044386, 'Std. Err': 0.03907904300395553, 'z-value': 3.8649648782671293, 'p-value': 0.00011110518605050856}, {'dest': 'TIB', 'op': '~', 'src': 'TIB_lag', 'Estimate': 0.4821569482185185, 'Std. Err': 0.03463169009106977, 'z-value': 13.922420388282653, 'p-value': 0.0}, {'dest': 'worry_scale_lag', 'op': '~', 'src': 'PANAS_NA_lag', 'Estimate': -0.42324649368683537, 'Std. Err': 0.03580860741516204, 'z-value': -11.819685942207435, 'p-value': 0.0}, {'dest': 'PHQ9', 'op': '~', 'src': 'PHQ9_lag', 'Estimate': 0.860519545934936, 'Std. Err': 0.02012657556120853, 'z-value': 42.75538793349054, 'p-value': 0.0}, {'dest': 'TST', 'op': '~', 'src': 'worry_scale', 'Estimate': 0.07701541600534663, 'Std. Err': 0.03723438639213097, 'z-value': 2.068394929144166, 'p-value': 0.038602901659403166}, {'dest': 'TST', 'op': '~', 'src': 'TST_lag', 'Estimate': 0.4021194344588681, 'Std. Err': 0.03607887257169463, 'z-value': 11.1455654177842, 'p-value': 0.0}, {'dest': 'PANAS_PA', 'op': '~', 'src': 'worry_scale', 'Estimate': 0.0680170501302313, 'Std. Err': 0.0190718014300951, 'z-value': 3.5663673605228894, 'p-value': 0.0003619638809171377}, {'dest': 'PANAS_PA', 'op': '~', 'src': 'PANAS_PA_lag', 'Estimate': 0.8702556411575659, 'Std. Err': 0.018610338445572378, 'z-value': 46.76194598265612, 'p-value': 0.0}, {'dest': 'alcohol_bev', 'op': '~', 'src': 'alcohol_bev_lag', 'Estimate': 0.651147620614118, 'Std. Err': 0.029990068402083188, 'z-value': 21.712108550815294, 'p-value': 0.0}, {'dest': 'PANAS_NA', 'op': '~~', 'src': 'PANAS_NA', 'Estimate': 0.4416891363177217, 'Std. Err': 0.024691173343239926, 'z-value': 17.888543819273824, 'p-value': 0.0}, {'dest': 'PANAS_PA_lag', 'op': '~~', 'src': 'PANAS_PA_lag', 'Estimate': 0.8648951793207981, 'Std. Err': 0.048349110359329386, 'z-value': 17.888543819628325, 'p-value': 0.0}, {'dest': 'PHQ9', 'op': '~~', 'src': 'PHQ9', 'Estimate': 0.25923906542072206, 'Std. Err': 0.01449190431760624, 'z-value': 17.888543818763935, 'p-value': 0.0}, {'dest': 'PHQ9_lag', 'op': '~~', 'src': 'PHQ9_lag', 'Estimate': 0.7709756645125868, 'Std. Err': 0.043098849871205415, 'z-value': 17.88854381958326, 'p-value': 0.0}, {'dest': 'TIB', 'op': '~~', 'src': 'TIB', 'Estimate': 0.7675297293770339, 'Std. Err': 0.04290621624097663, 'z-value': 17.888543819581393, 'p-value': 0.0}, {'dest': 'TST_lag', 'op': '~~', 'src': 'TST_lag', 'Estimate': 0.3898257805745108, 'Std. Err': 0.021791923618663087, 'z-value': 17.888543819177432, 'p-value': 0.0}, {'dest': 'alcohol_bev_lag', 'op' ...
# Value   76            93  1700.39609           0.0    6650.308723  0.752277
#
#             GFI     AGFI       NFI       TLI     RMSEA        AIC         BIC  \
# Value  0.744313  0.68712  0.744313  0.696865  0.182889  52.686262  182.068839
#
#          LogLik
# Value  2.656869  , 'model': <semopy.model.Model object at 0x7b88f55690d0>}}

# %% [markdown]
# Show the graph with just the directed edges.

# %%
# lets show the directed edges only
graph.show_graph(directed_only=True)

# %% [markdown]
# Lets make the nodes stand out. Let's highlight the lag variables
# by making them have a dotted outline and PANAS_PA to have a light green color, PANAS_NA to have a lightpink color and have alcohol_bev* have a rectangular shape and have a purple fill color.

# %%
node_styles = [
    {"pattern": "*_lag",        "style": "dotted"},
    {"pattern": "PANAS_PA*",    "style": "filled", "fillcolor": "lightgreen"},
    {"pattern": "PANAS_NA*",    "style": "filled", "fillcolor": "lightpink"},
    {"pattern": "PANAS_PA_lag", "style": "filled,dotted", "fillcolor": "lightgreen"},
    {"pattern": "PANAS_NA_lag", "style": "filled,dotted", "fillcolor": "lightpink"},
    {"pattern": "alcohol_bev*", "shape": "box", "style": "filled", "fillcolor": "purple", "fontcolor": "white"},
]

fc.show_styled_graph(graph, node_styles)

# %%
# Show styled graph with directed edges only
fc.show_styled_graph(graph, node_styles, directed_only=True)

# %% [markdown]
# ### *Multi-Graph Comparison*
#
# When comparing causal discovery results from different configurations, it helps to have nodes placed in the same positions across all graphs. The `show_n_graphs` method computes a shared layout from the union of all graphs and pins nodes at consistent coordinates. Disconnected nodes (those with no edges in a particular graph) are grayed out by default.

# %%
# Run two more model searches with different penalty discounts
result2, graph2 = fc.run_model_search(df_lag_std, 
                             model = 'gfci',
                             score={'sem_bic': {'penalty_discount': 2.0}},
                             test={"fisher_z": {"alpha": .01}},
                             knowledge=knowledge
                             )

result3, graph3 = fc.run_model_search(df_lag_std, 
                             model = 'gfci',
                             score={'sem_bic': {'penalty_discount': 3.0}},
                             test={"fisher_z": {"alpha": .01}},
                             knowledge=knowledge
                             )

# %%
# Compare three graphs side-by-side with shared node layout
# Use graph_size to force identical dimensions (width,height in inches)
# Nodes without edges in a graph are grayed out by default
fc.show_n_graphs(
    [graph, graph2, graph3],
    node_styles=node_styles,
    gray_disconnected=True,
    labels=["PD=1.0", "PD=2.0", "PD=3.0"],
    graph_size="10,8"
)
# Out:
# <div style="display:flex; gap:20px; align-items:flex-start; flex-wrap:wrap;"><div><img src="data:image/png;base64,..."/></div><div><img src="data:image/png;base64,..."/></div><div><img src="data:image/png;base64,..."/></div></div>
# [<graphviz.graphs.Digraph at 0x7b88d0c2a1b0>,
#  <graphviz.graphs.Digraph at 0x7b88d0bee570>,
#  <graphviz.graphs.Digraph at 0x7b88d0c2a300>]

# %%
# Compare three graphs with directed edges only
fc.show_n_graphs(
    [graph, graph2, graph3],
    node_styles=node_styles,
    gray_disconnected=True,
    directed_only=True,
    labels=["PD=1.0", "PD=2.0", "PD=3.0"],
    graph_size="10,8"
)
# Out:
# <div style="display:flex; gap:20px; align-items:flex-start; flex-wrap:wrap;"><div><img src="data:image/png;base64,..."/></div><div><img src="data:image/png;base64,..."/></div><div><img src="data:image/png;base64,..."/></div></div>
# [<graphviz.graphs.Digraph at 0x7b88d0c2a570>,
#  <graphviz.graphs.Digraph at 0x7b88d0c2a4b0>,
#  <graphviz.graphs.Digraph at 0x7b88d0c2a750>]

# %%
# Same comparison but without graying out disconnected nodes
fc.show_n_graphs(
    [graph, graph2, graph3],
    node_styles=node_styles,
    gray_disconnected=False,
    labels=["PD=1.0", "PD=2.0", "PD=3.0"],
    graph_size="10,8"
)
# Out:
# <div style="display:flex; gap:20px; align-items:flex-start; flex-wrap:wrap;"><div><img src="data:image/png;base64,..."/></div><div><img src="data:image/png;base64,..."/></div><div><img src="data:image/png;base64,..."/></div></div>
# [<graphviz.graphs.Digraph at 0x7b88d0c2a6f0>,
#  <graphviz.graphs.Digraph at 0x7b88f5624e60>,
#  <graphviz.graphs.Digraph at 0x7b88d0c2a930>]

# %%
# Save graphs to PNG files
fc.save_n_graphs(
    [graph, graph2, graph3],
    ["paired_graph_pd1", "paired_graph_pd2", "paired_graph_pd3"],
    node_styles=node_styles,
    gray_disconnected=True,
    labels=["PD=1.0", "PD=2.0", "PD=3.0"],
    graph_size="10,8",
    res=300
)
print("Saved: paired_graph_pd1.png, paired_graph_pd2.png, paired_graph_pd3.png")
# Out:
# Saved: paired_graph_pd1.png, paired_graph_pd2.png, paired_graph_pd3.png
