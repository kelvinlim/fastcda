# %% [markdown]
# Code to demonstrate basic FastCDA capabilities in a Jupyter notebook.

# %%
from fastcda import FastCDA
from dgraph_flex import DgraphFlex
import semopy
import pprint as pp

# create  an instance of FastCDA
fc = FastCDA()

# %% [markdown]
# ###  *Reading in data*
#
# For this demo, we are going to use a sample ema dataset that is built into
# the fastcda package.
#
# To read in your own csv data file "mydata.csv" you would
# use the pandas package, a very powerful package for working
# with dataframes.
#
# Here is the code:
# ```
# import pandas as pd
#
# df = pd.read_csv("mydata.csv")
#
# ```

# %%
# read in the sample ema dataset and view it
df = fc.getEMAData()

df

# %%
# add the lags, with a suffix of '_lag'
lag_stub = '_lag'
df_lag = fc.add_lag_columns(df, lag_stub=lag_stub)
df_lag

# %%
# standardize the data
df_lag_std = fc.standardize_df_cols(df_lag)
df_lag_std

# %%
# lets get the dataframe col names
cols = df.columns
cols

# %%
# Create the knowledge prior content for temporal
# order. The lag variables can only be parents of the non
# lag variables

knowledge = {'addtemporal': {
                            0: [col + lag_stub for col in cols],
                            1: [col for col in cols]
                            }
            }
knowledge

# %%
# run model with run_model_search
result, graph = fc.run_model_search(df_lag_std, 
                             model = 'gfci',
                             score={'sem_bic': {'penalty_discount': 1.0}},
                             test={"fisher_z": {"alpha": .01}},
                             knowledge=knowledge
                             )

# %%
graph.show_graph()

# %% [markdown]
# Show the graph with just the directed edges.

# %%
# lets show the directed edges only
graph.show_graph(directed_only=True)

# %% [markdown]
# Lets make the nodes stand out. Let's highlight the lag variables
# by making them have a dotted outline and PANAS_PA to have a light green color, PANAS_NA to have a lightpink color and have alcohol_bev* have a rectangular shape and have a purple fill color.

# %%
node_styles = [
    {"pattern": "*_lag",        "style": "dotted"},
    {"pattern": "PANAS_PA*",    "style": "filled", "fillcolor": "lightgreen"},
    {"pattern": "PANAS_NA*",    "style": "filled", "fillcolor": "lightpink"},
    {"pattern": "PANAS_PA_lag", "style": "filled,dotted", "fillcolor": "lightgreen"},
    {"pattern": "PANAS_NA_lag", "style": "filled,dotted", "fillcolor": "lightpink"},
    {"pattern": "alcohol_bev*", "shape": "box", "style": "filled", "fillcolor": "purple", "fontcolor": "white"},
]

fc.show_styled_graph(graph, node_styles)

# %%
# Show styled graph with directed edges only
fc.show_styled_graph(graph, node_styles, directed_only=True)

# %% [markdown]
# ### *Multi-Graph Comparison*
#
# When comparing causal discovery results from different configurations, it helps to have nodes placed in the same positions across all graphs. The `show_n_graphs` method computes a shared layout from the union of all graphs and pins nodes at consistent coordinates. Disconnected nodes (those with no edges in a particular graph) are grayed out by default.

# %%
# Run two more model searches with different penalty discounts
result2, graph2 = fc.run_model_search(df_lag_std, 
                             model = 'gfci',
                             score={'sem_bic': {'penalty_discount': 2.0}},
                             test={"fisher_z": {"alpha": .01}},
                             knowledge=knowledge
                             )

result3, graph3 = fc.run_model_search(df_lag_std, 
                             model = 'gfci',
                             score={'sem_bic': {'penalty_discount': 3.0}},
                             test={"fisher_z": {"alpha": .01}},
                             knowledge=knowledge
                             )

# %%
# Compare three graphs side-by-side with shared node layout
# Use graph_size to force identical dimensions (width,height in inches)
# Nodes without edges in a graph are grayed out by default
fc.show_n_graphs(
    [graph, graph2, graph3],
    node_styles=node_styles,
    gray_disconnected=True,
    labels=["PD=1.0", "PD=2.0", "PD=3.0"],
    graph_size="10,8"
)

# %%
# Compare three graphs with directed edges only
fc.show_n_graphs(
    [graph, graph2, graph3],
    node_styles=node_styles,
    gray_disconnected=True,
    directed_only=True,
    labels=["PD=1.0", "PD=2.0", "PD=3.0"],
    graph_size="10,8"
)

# %%
# Same comparison but without graying out disconnected nodes
fc.show_n_graphs(
    [graph, graph2, graph3],
    node_styles=node_styles,
    gray_disconnected=False,
    labels=["PD=1.0", "PD=2.0", "PD=3.0"],
    graph_size="10,8"
)

# %%
# Save graphs to PNG files
fc.save_n_graphs(
    [graph, graph2, graph3],
    ["paired_graph_pd1", "paired_graph_pd2", "paired_graph_pd3"],
    node_styles=node_styles,
    gray_disconnected=True,
    labels=["PD=1.0", "PD=2.0", "PD=3.0"],
    graph_size="10,8",
    res=300
)
print("Saved: paired_graph_pd1.png, paired_graph_pd2.png, paired_graph_pd3.png")

# %% [markdown]
# ---
#
# ## Background Knowledge: `forbiddirect` and `requiredirect`
#
# Beyond temporal ordering (`addtemporal`), you can inject two other types of prior knowledge:
#
# - **`forbiddirect`**: a list of `[parent, child]` pairs — the algorithm will *not* produce those directed edges
# - **`requiredirect`**: a list of `[parent, child]` pairs — the algorithm *must* include those directed edges
#
# Both keys can be combined with `addtemporal` in the same `knowledge` dict.
#
# To demonstrate, we generate a synthetic wellness dataset with a known causal structure.

# %%
import numpy as np
import pandas as pd

# Synthetic wellness dataset — true causal DAG:
#   exercise  -->  stress        (−1.5)
#   exercise  -->  mood          (+1.0)
#   caffeine  -->  stress        (+0.8)
#   caffeine  -->  sleep         (−1.2)
#   stress    -->  sleep         (−1.0)
#   stress    -->  mood          (−0.8)
#   sleep     -->  mood          (+1.2)
#   mood      -->  productivity  (+1.5)

rng = np.random.default_rng(42)
n = 500
noise = 0.3

exercise  = rng.standard_normal(n)
caffeine  = rng.standard_normal(n)
stress    = -1.5*exercise + 0.8*caffeine + noise*rng.standard_normal(n)
sleep     = -1.2*caffeine - 1.0*stress   + noise*rng.standard_normal(n)
mood      = (1.0*exercise - 0.8*stress   + 1.2*sleep + noise*rng.standard_normal(n))
productivity = 1.5*mood + noise*rng.standard_normal(n)

df_syn = pd.DataFrame({
    'exercise': exercise,
    'caffeine': caffeine,
    'stress':   stress,
    'sleep':    sleep,
    'mood':     mood,
    'productivity': productivity,
})

# Standardize before passing to GFCI
df_syn_std = fc.standardize_df_cols(df_syn)
df_syn_std

# %% [markdown]
# ### Baseline — no constraints
#
# Run GFCI with no prior knowledge to see what the algorithm discovers on its own.

# %%
# Baseline: no background knowledge
result_base, graph_base = fc.run_model_search(
    df_syn_std,
    model='gfci',
    score={'sem_bic': {'penalty_discount': 1.0}},
    test={'fisher_z': {'alpha': 0.01}},
)
graph_base.show_graph()

# %% [markdown]
# ### `forbiddirect` — block a specific directed edge
#
# Suppose domain theory tells us that caffeine does *not* directly cause stress (any effect is indirect or spurious). We forbid the `caffeine → stress` edge and see how the graph changes.

# %%
# forbiddirect: block caffeine --> stress
knowledge_forbid = {
    'forbiddirect': [['caffeine', 'stress']]
}

result_forbid, graph_forbid = fc.run_model_search(
    df_syn_std,
    model='gfci',
    score={'sem_bic': {'penalty_discount': 1.0}},
    test={'fisher_z': {'alpha': 0.01}},
    knowledge=knowledge_forbid,
)
graph_forbid.show_graph()

# %% [markdown]
# ### `requiredirect` — force a specific directed edge
#
# Now suppose theory strongly asserts that exercise has a direct effect on productivity (beyond the mediated path exercise → mood → productivity). We require that edge, even if GFCI would not discover it on its own.

# %%
# requiredirect: force exercise --> productivity
knowledge_require = {
    'requiredirect': [['exercise', 'productivity']]
}

result_req, graph_req = fc.run_model_search(
    df_syn_std,
    model='gfci',
    score={'sem_bic': {'penalty_discount': 1.0}},
    test={'fisher_z': {'alpha': 0.01}},
    knowledge=knowledge_require,
)
graph_req.show_graph()

# %% [markdown]
# ### Combined — `forbiddirect` + `requiredirect` together
#
# Both constraint types can be combined in a single `knowledge` dict. Here we apply both at once and compare all four graphs side-by-side using a shared node layout so the differences are immediately visible.

# %%
# Combined: forbid caffeine --> stress AND require exercise --> productivity
knowledge_combined = {
    'forbiddirect':  [['caffeine', 'stress']],
    'requiredirect': [['exercise', 'productivity']],
}

result_comb, graph_comb = fc.run_model_search(
    df_syn_std,
    model='gfci',
    score={'sem_bic': {'penalty_discount': 1.0}},
    test={'fisher_z': {'alpha': 0.01}},
    knowledge=knowledge_combined,
)

# Compare all four side-by-side with a shared layout
fc.show_n_graphs(
    [graph_base, graph_forbid, graph_req, graph_comb],
    gray_disconnected=True,
    labels=["Baseline", "forbiddirect", "requiredirect", "Combined"],
    graph_size="10,8",
)
